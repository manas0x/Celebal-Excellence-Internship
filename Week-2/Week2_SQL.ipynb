# %% [markdown]
# # Celebal Summer Internship 2026
# ## Week 2 – E-Commerce Sales Database
#
# **Author:** Manas Arora
# **Role:** Data Engineering Intern
#
# ---
#
# ### Repository Structure
#
# - `CELEBAL INTERNSHIP ASSIGNMENT.pdf` – Assignment
# - `Week2_SQL.ipynb` – Solutions to all questions
# - `solutions.sql` – Solutions queries
# - `db.sql` – Database schema and sample data
# - `README.md` – Project overview
#
# This notebook documents my SQL solutions and reasoning for the Week 2 internship assignment.

# %% [markdown]
# ## Objectives
#
# - Design and understand a relational database
# - Practice SQL querying
# - Learn filtering, aggregation, joins, transactions and constraints
# - Document results in a reproducible notebook

# %% [markdown]
# ## Database Schema
#
# The database contains four tables:
#
# 1. customers
# 2. products
# 3. orders
# 4. order_items
#
# Relationship:
#
# ```
# customers
#     │
#     └──── orders
#               │
#               └──── order_items
#                        │
#                        └──── products
# ```

# %% [markdown]
# ## Setup
#
# Run the SQL statements from **db.sql** or **solutions.sql** to:
#
# 1. Create the database
# 2. Create all tables
# 3. Insert sample data
#
# After loading the data, here are the solutions to each question.

# %% [markdown]
# # Question 1
#
# **Question:** Write a query to retrieve all columns for all customers.

# %%
SELECT * FROM customers;

# %% [markdown]
# ### Output
#
# ![Q1](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q1.png)

# %% [markdown]
# # Question 2
#
# **Question:** Write a query to retrieve only the first_name, last_name, and city of all customers.

# %%
SELECT first_name, last_name, city FROM customers;

# %% [markdown]
# ### Output
#
# ![Q2](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q2.png)

# %% [markdown]
# # Question 3
#
# **Question:** Write a query to find all unique product categories available in the products table.

# %%
SELECT DISTINCT category FROM products;

# %% [markdown]
# ### Output
#
# ![Q3](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q3.png)

# %% [markdown]
# # Question 4
#
# **Question:** Identify all primary keys in the database. Why are primary keys important?

# %%
-- Primary keys uniquely identify each record in a table.
-- In this DB, they are: customers(customer_id), products(product_id), orders(order_id), order_items(item_id).

# %% [markdown]
# # Question 5
#
# **Question:** Insert a new customer into the customers table.

# %%
INSERT INTO customers VALUES (109, 'Test', 'User', 'aarav.s@email.com', 'Mumbai', 'Maharashtra', '2024-09-01', FALSE);

# %% [markdown]
# ### Output
#
# *(No output image provided)*

# %% [markdown]
# # Question 6
#
# **Question:** Try inserting a product with unit_price = -50. What happens and which constraint prevents it? Write the INSERT statement and explain the error.

# %%
INSERT INTO products VALUES (209, 'Broken Item', 'Electronics', 'TestBrand', -50.00, 100);

# %% [markdown]
# # Question 7
#
# **Question:** Retrieve all orders with status = 'Delivered'.

# %%
SELECT * FROM orders WHERE status = 'Delivered';

# %% [markdown]
# ### Output
#
# ![Q7](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q7.png)

# %% [markdown]
# # Question 8
#
# **Question:** Find all products in the 'Electronics' category with a unit_price greater than ₹2000.

# %%
SELECT * FROM products WHERE category = 'Electronics' AND unit_price > 2000;

# %% [markdown]
# ### Output
#
# ![Q8](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q8.png)

# %% [markdown]
# # Question 9
#
# **Question:** List all customers who joined in the year 2024 and belong to the state 'Maharashtra'.

# %%
SELECT * FROM customers WHERE YEAR(join_date) = 2024 AND state = 'Maharashtra';

# %% [markdown]
# ### Output
#
# ![Q9](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q9.png)

# %% [markdown]
# # Question 10
#
# **Question:** Find all orders placed between '2024-08-10' and '2024-08-25' (inclusive) that are NOT cancelled.

# %%
SELECT * FROM orders
WHERE order_date BETWEEN '2024-08-10' AND '2024-08-25'
  AND status <> 'Cancelled';

# %% [markdown]
# ### Output
#
# ![Q10](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q10.png)

# %% [markdown]
# # Question 11
#
# **Question:** Explain what idx_orders_date does and how it improves performance. Write a sample query that benefits from this index.

# %%
SELECT * FROM orders WHERE order_date BETWEEN '2024-08-01' AND '2024-08-15';

# %% [markdown]
# # Question 12
#
# **Question:** If you run SELECT * FROM customers WHERE YEAR(join_date) = 2024; — would the index on join_date be used? Rewrite to be SARGable.

# %%
SELECT * FROM customers WHERE join_date >= '2024-01-01' AND join_date < '2025-01-01';

# %% [markdown]
# ### Output
#
# ![Q12](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q12.png)

# %% [markdown]
# # Question 13
#
# **Question:** Count the total number of orders in the orders table.

# %%
SELECT COUNT(*) AS total_orders FROM orders;

# %% [markdown]
# ### Output
#
# ![Q13](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q13.png)

# %% [markdown]
# # Question 14
#
# **Question:** Find the total revenue (SUM of total_amount) from all 'Delivered' orders.

# %%
SELECT SUM(total_amount) AS total_revenue FROM orders WHERE status = 'Delivered';

# %% [markdown]
# ### Output
#
# ![Q14](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q14.png)

# %% [markdown]
# # Question 15
#
# **Question:** Calculate the average unit_price of products in each category.

# %%
SELECT category, AVG(unit_price) AS avg_price
FROM products
GROUP BY category;

# %% [markdown]
# ### Output
#
# ![Q15](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q15.png)

# %% [markdown]
# # Question 16
#
# **Question:** For each order status, find the count of orders and total revenue. Sort by total revenue descending.

# %%
SELECT status,
       COUNT(*) AS order_count,
       SUM(total_amount) AS total_revenue
FROM orders
GROUP BY status
ORDER BY total_revenue DESC;

# %% [markdown]
# ### Output
#
# ![Q16](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q16.png)

# %% [markdown]
# # Question 17
#
# **Question:** Find the most expensive (MAX) and cheapest (MIN) product in each category.

# %%
SELECT category,
       MAX(unit_price) AS max_price,
       MIN(unit_price) AS min_price
FROM products
GROUP BY category;

# %% [markdown]
# ### Output
#
# ![Q17](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q17.png)

# %% [markdown]
# # Question 18
#
# **Question:** List all product categories where the average unit_price is greater than ₹2000.

# %%
SELECT category, AVG(unit_price) AS avg_price
FROM products
GROUP BY category
HAVING AVG(unit_price) > 2000;

# %% [markdown]
# ### Output
#
# ![Q18](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q18.png)

# %% [markdown]
# # Question 19
#
# **Question:** INNER JOIN: Display each order with the customer's first_name and last_name. Show: order_id, order_date, first_name, last_name, total_amount.

# %%
SELECT o.order_id, o.order_date,
       c.first_name, c.last_name,
       o.total_amount
FROM orders o
INNER JOIN customers c ON o.customer_id = c.customer_id;

# %% [markdown]
# ### Output
#
# ![Q19](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q19.png)

# %% [markdown]
# # Question 20
#
# **Question:** LEFT JOIN: List ALL customers and their orders (if any). Customers with no orders show NULL for order columns.

# %%
SELECT c.customer_id, c.first_name, c.last_name,
       o.order_id, o.order_date, o.total_amount
FROM customers c
LEFT JOIN orders o ON c.customer_id = o.customer_id;

# %% [markdown]
# ### Output
#
# ![Q20](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q20.png)

# %% [markdown]
# # Question 21
#
# **Question:** Join orders → order_items → products to show: order_id, product_name, quantity, unit_price, discount_pct.

# %%
SELECT o.order_id,
       p.product_name,
       oi.quantity,
       oi.unit_price,
       oi.discount_pct
FROM orders o
JOIN order_items oi ON o.order_id = oi.order_id
JOIN products p     ON oi.product_id = p.product_id;

# %% [markdown]
# ### Output
#
# ![Q21](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q21.png)

# %% [markdown]
# # Question 22
#
# **Question:** Explain the difference between LEFT JOIN and RIGHT JOIN. When would you use a FULL OUTER JOIN?

# %%
SELECT c.first_name, o.order_id
FROM customers c LEFT JOIN orders o ON c.customer_id = o.customer_id
UNION
SELECT c.first_name, o.order_id
FROM customers c RIGHT JOIN orders o ON c.customer_id = o.customer_id;

# %% [markdown]
# ### Output
#
# ![Q22](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q22.png)

# %% [markdown]
# # Question 23
#
# **Question:** Identify all Foreign Key relationships. What happens if you insert an order with customer_id = 999?

# %%
INSERT INTO orders VALUES (1011, 999, '2024-09-01', 'Pending', 500.00);

# %% [markdown]
# # Question 24
#
# **Question:** Use CASE to classify products into price tiers: Budget (<1000), Mid-Range (1000–3000), Premium (>3000).

# %%
SELECT product_name,
       unit_price,
       CASE
         WHEN unit_price < 1000               THEN 'Budget'
         WHEN unit_price BETWEEN 1000 AND 3000 THEN 'Mid-Range'
         ELSE 'Premium'
       END AS price_tier
FROM products;

# %% [markdown]
# ### Output
#
# ![Q24](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q24.png)

# %% [markdown]
# # Question 25
#
# **Question:** Using CASE inside an aggregate, count 'Delivered' vs 'Not Delivered' orders in a single row.

# %%
SELECT
  SUM(CASE WHEN status = 'Delivered'  THEN 1 ELSE 0 END) AS delivered,
  SUM(CASE WHEN status <> 'Delivered' THEN 1 ELSE 0 END) AS not_delivered
FROM orders;

# %% [markdown]
# # Question 26
#
# **Question:** Explain each letter of ACID with a real-world bank transfer example.

# %%
-- A - Atomicity: All operations succeed or all rollback.
-- C - Consistency: Transaction brings DB from valid state to another valid state.
-- I - Isolation: Concurrent transactions don't interfere.
-- D - Durability: Changes are permanent after commit.

# %% [markdown]
# # Question 27
#
# **Question:** Write a SQL transaction: insert order 1011, insert 2 order items, update stock_qty. ROLLBACK on failure, else COMMIT.

# %%
START TRANSACTION;
INSERT INTO orders VALUES
  (1011, 102, CURDATE(), 'Pending', 1598.00);
INSERT INTO order_items VALUES
  (5016, 1011, 206, 1, 1299.00, 0),
  (5017, 1011, 208, 1,  599.00, 0);
UPDATE products SET stock_qty = stock_qty - 1 WHERE product_id = 206;
UPDATE products SET stock_qty = stock_qty - 1 WHERE product_id = 208;
COMMIT;

# %% [markdown]
# ### Output
#
# ![Q27](https://raw.githubusercontent.com/manas0x/Celebal-Excellence-Internship/main/Week-2/images/Q27.png)
